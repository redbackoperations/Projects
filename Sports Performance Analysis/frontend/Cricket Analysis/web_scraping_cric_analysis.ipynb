# %% [markdown]
# #### Using read_html function to read data from cricinfo website

# %%
import pandas as pd

# %%
url = 'https://www.espncricinfo.com/records/tournament/team-match-results/icc-cricket-world-cup-2023-24-15338'

# %%
tables = pd.read_html(url)

# %% [markdown]
# #### Printing the number of tables on the webpage

# %%
print(len(tables))
# Out:
# 1

# %%
tables[0]
# Out:
#           Team 1        Team 2        Winner     Margin        Ground  \
# 0          India     Australia     Australia  6 wickets     Ahmedabad
# 1      Australia  South Africa     Australia  3 wickets  Eden Gardens
# 2          India   New Zealand         India    70 runs      Wankhede
# 3          India   Netherlands         India   160 runs     Bengaluru
# 4        England      Pakistan       England    93 runs  Eden Gardens
# 5      Australia    Bangladesh     Australia  8 wickets          Pune
# 6    Afghanistan  South Africa  South Africa  5 wickets     Ahmedabad
# 7    New Zealand     Sri Lanka   New Zealand  5 wickets     Bengaluru
# 8        England   Netherlands       England   160 runs          Pune
# 9    Afghanistan     Australia     Australia  3 wickets      Wankhede
# 10    Bangladesh     Sri Lanka    Bangladesh  3 wickets         Delhi
# 11         India  South Africa         India   243 runs  Eden Gardens
# ...

# %%
reqd_table = tables[0]

# %%
type(tables)
# Out:
# list

# %% [markdown]
# #### Converting the list to dataframe

# %%
pd.DataFrame(reqd_table)
# Out:
#           Team 1        Team 2        Winner     Margin        Ground  \
# 0          India     Australia     Australia  6 wickets     Ahmedabad
# 1      Australia  South Africa     Australia  3 wickets  Eden Gardens
# 2          India   New Zealand         India    70 runs      Wankhede
# 3          India   Netherlands         India   160 runs     Bengaluru
# 4        England      Pakistan       England    93 runs  Eden Gardens
# 5      Australia    Bangladesh     Australia  8 wickets          Pune
# 6    Afghanistan  South Africa  South Africa  5 wickets     Ahmedabad
# 7    New Zealand     Sri Lanka   New Zealand  5 wickets     Bengaluru
# 8        England   Netherlands       England   160 runs          Pune
# 9    Afghanistan     Australia     Australia  3 wickets      Wankhede
# 10    Bangladesh     Sri Lanka    Bangladesh  3 wickets         Delhi
# 11         India  South Africa         India   243 runs  Eden Gardens
# ...

# %% [markdown]
# #### Converting the data frame into a csv file and saving it

# %%
reqd_table.to_csv('match_summary.csv')

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# Replace 'url' with the actual URL of the HTML page
url = 'https://www.espncricinfo.com/records/tournament/team-match-results/icc-cricket-world-cup-2023-24-15338'

# Send an HTTP request to the webpage and get the HTML content
response = requests.get(url)
html_content = response.text

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find all the tables in the HTML page
tables = soup.find_all('table')

# Extract and print the names of the tables
for index, table in enumerate(tables, start=1):
    # You can customize how you want to get the table name based on your HTML structure
    # For example, you might use the table's id or class attribute
    table_name = f'Table_{index}'  # Replace with your logic to get the actual table name
    print(f'Table Name: {table_name}')
# Out:
# Table Name: Table_1

# %% [markdown]
# #### Listing the urls correspoding to each anchor tag in the match_summary table

# %%
import requests
from bs4 import BeautifulSoup

# Replace 'url' with the actual URL of the webpage containing the HTML table
url = 'https://www.espncricinfo.com/records/tournament/team-match-results/icc-cricket-world-cup-2023-24-15338'

# Send an HTTP request to the webpage and get the HTML content
response = requests.get(url)
html_content = response.text

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Locate the HTML table using appropriate tags and attributes
# For example, if the table has the id 'my-table', you can use: table = soup.find('table', {'id': 'my-table'})
table = soup.find('table')

# Initialize a list to store the extracted links
links = []

# Iterate through each row in the table
for row in table.find_all('tr'):
    # Find all the anchor tags (links) in each row
    for link in row.find_all('a', href=True):
        # Get the value of the 'href' attribute (link)
        href = link['href']
        # Append the link to the 'links' list
        links.append(href)

# Print the collected links
for link in links:
    print(link)
# Out:
# /cricket-grounds/narendra-modi-stadium-motera-ahmedabad-57851
# /series/icc-cricket-world-cup-2023-24-1367856/india-vs-australia-final-1384439/full-scorecard
# /cricket-grounds/eden-gardens-kolkata-57980
# /series/icc-cricket-world-cup-2023-24-1367856/australia-vs-south-africa-2nd-semi-final-1384438/full-scorecard
# /cricket-grounds/wankhede-stadium-mumbai-58324
# /series/icc-cricket-world-cup-2023-24-1367856/india-vs-new-zealand-1st-semi-final-1384437/full-scorecard
# /cricket-grounds/m-chinnaswamy-stadium-bengaluru-57897
# /series/icc-cricket-world-cup-2023-24-1367856/india-vs-netherlands-45th-match-1384436/full-scorecard
# /cricket-grounds/eden-gardens-kolkata-57980
# /series/icc-cricket-world-cup-2023-24-1367856/england-vs-pakistan-44th-match-1384435/full-scorecard
# /cricket-grounds/maharashtra-cricket-association-stadium-pune-545380
# /series/icc-cricket-world-cup-2023-24-1367856/australia-vs-bangladesh-43rd-match-1384434/full-scorecard
# ...

# %%
type(links)
# Out:
# list

# %% [markdown]
# #### Filtering the urls correspoding to the ground information alone

# %%
links1 = links[::2]

# %%
print(links1)
# Out:
# ['/cricket-grounds/narendra-modi-stadium-motera-ahmedabad-57851', '/cricket-grounds/eden-gardens-kolkata-57980', '/cricket-grounds/wankhede-stadium-mumbai-58324', '/cricket-grounds/m-chinnaswamy-stadium-bengaluru-57897', '/cricket-grounds/eden-gardens-kolkata-57980', '/cricket-grounds/maharashtra-cricket-association-stadium-pune-545380', '/cricket-grounds/narendra-modi-stadium-motera-ahmedabad-57851', '/cricket-grounds/m-chinnaswamy-stadium-bengaluru-57897', '/cricket-grounds/maharashtra-cricket-association-stadium-pune-545380', '/cricket-grounds/wankhede-stadium-mumbai-58324', '/cricket-grounds/arun-jaitley-stadium-delhi-58040', '/cricket-grounds/eden-gardens-kolkata-57980', '/cricket-grounds/narendra-modi-stadium-motera-ahmedabad-57851', '/cricket-grounds/m-chinnaswamy-stadium-bengaluru-57897', '/cricket-grounds/bharat-ratna-shri-atal-bihari-vajpayee-ekana-cricket-stadium-lucknow-1070094', '/cricket-grounds/wankhede-stadium-mumbai-58324', '/cricket-grounds/maharashtra-cricket-assoc
# ...

# %%
type(links1)
# Out:
# list

# %% [markdown]
# #### Finally filtering the urls of all the 48 matches in the world cup

# %%
# Use list comprehension to create a new list without elements from list2
result_list = []
for item in links:
    if item not in links1:
               result_list.append(item)

print(result_list)
# Out:
# ['/series/icc-cricket-world-cup-2023-24-1367856/india-vs-australia-final-1384439/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-south-africa-2nd-semi-final-1384438/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/india-vs-new-zealand-1st-semi-final-1384437/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/india-vs-netherlands-45th-match-1384436/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/england-vs-pakistan-44th-match-1384435/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-bangladesh-43rd-match-1384434/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-south-africa-42nd-match-1384433/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/new-zealand-vs-sri-lanka-41st-match-1384432/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1367856/england-vs-netherlands-40th-match-1384431/full-scorecard', '/series/icc-cricket-world-cup-2023-24-1
# ...

# %%
len(result_list)
# Out:
# 48

# %%
url = 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/england-vs-new-zealand-1st-match-1384392/full-scorecard'

# %%
match_tables = pd.read_html(url)

# %%
#Displaying one messy table
match_tables[1]
# Out:
#                                               BOWLING  \
# 0                                         Trent Boult
# 1   38.5 to LS Livingstone, chipped straight to lo...
# 2                                          Matt Henry
# 3   7.4 to DJ Malan, edged and gone this time! Mal...
# 4                                    Mitchell Santner
# 5   12.5 to JM Bairstow, checked drive to wide lon...
# 6                                       James Neesham
# 7                                     Rachin Ravindra
# 8   16.6 to HC Brook, Ravindra strikes back. One o...
# 9                                      Glenn Phillips
# 10  21.2 to MM Ali, Moeen was sent to tackle Ravin...
#
#                                                     O  \
# 0                                                  10
# 1   38.5 to LS Livingstone, chipped straight to lo...
# 2                                                  10
# 3   7.4 to DJ Malan, edged and gone this time! Mal...
# ...
